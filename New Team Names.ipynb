# %% [markdown]
# Team names to be renamed to.
#
# -Kwasie Agbemadon :)

# %%
import pandas as pd
ratings = pd.read_excel('madden_nfl_23_player_ratings.xlsx')
ratings
# Out:
#             Team Position       Full Name  Overall Rating  Jersey Number  \
# 0           Rams       RE    Aaron Donald              99             99
# 1        Raiders       WR   Davante Adams              99             17
# 2         Browns       RE   Myles Garrett              99             95
# 3          49ers       LT  Trent Williams              99             71
# 4           Rams       WR     Cooper Kupp              98             10
# ...          ...      ...             ...             ...            ...
# 2363     Jaguars       TE   Ross Matiscik              26             46
# 2364  Buccaneers       TE     Zach Triner              26             97
# 2365    Patriots       TE     Joe Cardona              25             49
# 2366        Rams       TE  Matthew Orzech              25             42
# 2367      Saints       TE       Zach Wood              25             49
#
#       Awareness  Speed  Acceleration  Agility  Jumping  ...       Archetype  \
# ...

# %%
ratings.Team.unique()
new_names = {'Rams': 'Los Angeles Rams', 
             'Raiders': 'Las Vegas Raiders', 
             'Browns': 'Cleveland Browns', 
             '49ers': 'San Francisco 49ers', 
             'Chiefs': 'Kansas City Chiefs', 
             'Cowboys': 'Dallas Cowboys', 
             'Titans': 'Tennessee Titans', 
             'Bucaneers': 'Tampa Bay Bucaneers', 
             'Dolphins': 'Miami Dolphins', 
             'Packers': 'Green Bay Packers', 
             'Panthers': 'Carolina Panthers', 
             'Cardinals': 'Arizona Cardinals', 
             'Steelers': 'Pittsburgh Steelers', 
             'Colts': 'Indianapolis Colts', 
             'Bills': 'Buffalo Bills', 
             'Vikings': 'Minnesota Vikings', 
             'Saints': 'New Orleans Saints', 
             'Chargers': 'Los Angeles Chargers', 
             'Bengals': 'Cicinnati Bengals', 
             'Ravens': 'Baltimore Ravens', 
             'Eagles': 'Philadelphia Eagles', 
             'Commanders': 'Washington Commanders', 
             'Broncos': 'Denver Broncos', 
             'Seahawks': 'Seattle Seahawks', 
             'Falcons': 'Atlanta Falcons', 
             'Bears': 'Chicago Bears', 
             'Lions': 'Detroit Lions', 
             'Texans': 'Houston Texans', 
             'Jaguars': 'Jacksonville Jaguars', 
             'Patriots': 'New England Patriots', 
             'Jets': 'New York Jets', 
             'Giants': 'New York Giants'}

# %%
ratings.Team.replace(new_names, inplace=True)

# %%
ratings
# Out:
#                       Team Position       Full Name  Overall Rating  \
# 0         Los Angeles Rams       RE    Aaron Donald              99
# 1        Las Vegas Raiders       WR   Davante Adams              99
# 2         Cleveland Browns       RE   Myles Garrett              99
# 3      San Francisco 49ers       LT  Trent Williams              99
# 4         Los Angeles Rams       WR     Cooper Kupp              98
# ...                    ...      ...             ...             ...
# 2363  Jacksonville Jaguars       TE   Ross Matiscik              26
# 2364            Buccaneers       TE     Zach Triner              26
# 2365  New England Patriots       TE     Joe Cardona              25
# 2366      Los Angeles Rams       TE  Matthew Orzech              25
# 2367    New Orleans Saints       TE       Zach Wood              25
#
#       Jersey Number  Awareness  Speed  Acceleration  Agility  Jumping  ...  \
# ...
